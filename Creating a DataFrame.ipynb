# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib as mlp

# %%
sample = pd.Series(["Levi's", "AT&T"])
#Create a series named 'sample' and assign index to each value
sample
#Print this series
# Out:
# 0    Levi's
# 1      AT&T
# dtype: object

# %%
#Create dataframe called 'df_new' with two columns 
df_new = pd.DataFrame(columns = ["High", "Low"])
df_new
# Out:
# Empty DataFrame
# Columns: [High, Low]
# Index: []

# %%
#Assign the series 'sample' to the column 'High'
df_new["High"] = sample
df_new
# Out:
#      High  Low
# 0  Levi's  NaN
# 1    AT&T  NaN

# %%
#You have now created a dataframe with two columns and two index values

# %%
sample_two = pd.Series(["Verizon", "Wrangler", "Gucci", "Volkswagen", "Whatever"])

# %%
df_new["Low"]=sample_two
df_new
# Out:
#      High       Low
# 0  Levi's   Verizon
# 1    AT&T  Wrangler

# %%
#Construct DataFrames using Dictionaries

# %%
dict_new = {'City':['SF', 'LA', 'NYC'], 'Population':[30, 20, 50]}
dict_new
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [30, 20, 50]}

# %%
df2_new = pd.DataFrame(dict_new)
df2_new
# Out:
#   City  Population
# 0   SF          30
# 1   LA          20
# 2  NYC          50

# %%
dualsim_df = pd.read_clipboard()

# %%
del dualsim_df['MO'] 
#= dualsim_df(columns = "User")
dualsim_df
# Out:
#      SMS  Attempt    MT  SMS.1 Attempt.1           AON  months  Value  \
# 0      1      1.0   4.0    6.6       MVC    299.285000     NaN    NaN
# 1      2      4.0   8.0    4.8       MVC     97.958333     NaN    NaN
# 2      3      0.0  17.0    2.3       MVC     43.393333     NaN    NaN
# 3      4      0.0   3.0    2.0       MVC    383.150000     NaN    NaN
# 4      5      2.0   3.0    4.0       MVC    197.920000     NaN    NaN
# 5      6    144.0  13.0    2.1       MVC     56.968333     NaN    NaN
# 6      7      1.0  16.0    0.4       LVC    346.075000     NaN    NaN
# 7      8      0.0   2.0  125.0       MVC    778.611667     NaN    NaN
# 8      9      4.0   6.0   96.8       LVC   1190.498333     NaN    NaN
# 9     10      0.0  13.0  112.9       MVC   2187.613333     NaN    NaN
# 10    11      0.0   4.0   76.3       LVC    120.680000     NaN    NaN
# 11    12      8.0   2.0   81.9       MVC   1195.643333     NaN    NaN
# ...

# %%
dualsim_df.columns = ["User", "SMS_Out", "SMS_In", "Voice_MT", "AON", "x", "y", "z", "u", "v", "z", "z1", "z2", "z3"]

# %%
dualsim_df
# Out:
#      User  SMS_Out  SMS_In  Voice_MT  AON             x   y   z   u   v   z  \
# 0       1      1.0     4.0       6.6  MVC    299.285000 NaN NaN NaN NaN NaN
# 1       2      4.0     8.0       4.8  MVC     97.958333 NaN NaN NaN NaN NaN
# 2       3      0.0    17.0       2.3  MVC     43.393333 NaN NaN NaN NaN NaN
# 3       4      0.0     3.0       2.0  MVC    383.150000 NaN NaN NaN NaN NaN
# 4       5      2.0     3.0       4.0  MVC    197.920000 NaN NaN NaN NaN NaN
# 5       6    144.0    13.0       2.1  MVC     56.968333 NaN NaN NaN NaN NaN
# 6       7      1.0    16.0       0.4  LVC    346.075000 NaN NaN NaN NaN NaN
# 7       8      0.0     2.0     125.0  MVC    778.611667 NaN NaN NaN NaN NaN
# 8       9      4.0     6.0      96.8  LVC   1190.498333 NaN NaN NaN NaN NaN
# 9      10      0.0    13.0     112.9  MVC   2187.613333 NaN NaN NaN NaN NaN
# 10     11      0.0     4.0      76.3  LVC    120.680000 NaN NaN NaN NaN NaN
# ...

# %%
dualsim_df = dualsim_df.pivot('SMS_Out','SMS_In','x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-48c555d70530> in <module>()
# ----> 1 dualsim_df = dualsim_df.pivot('SMS_Out','SMS_In','x')
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in pivot(self, index, columns, values)
#    3844         """
#    3845         from pandas.core.reshape import pivot
# -> 3846         return pivot(self, index=index, columns=columns, values=values)
#    3847
#    3848     def stack(self, level=-1, dropna=True):
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/reshape.pyc in pivot(self, index, columns, values)
#     330         indexed = Series(self[values].values,
#     331                          index=MultiIndex.from_arrays([index, self[columns]]))
# --> 332         return indexed.unstack(columns)
#     333
#     334
#
# ...
